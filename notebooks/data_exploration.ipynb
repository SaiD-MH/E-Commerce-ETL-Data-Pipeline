# %%
#open the file 

import pandas as pd

# %%
df = pd.read_csv("../data/data_14-12-2025.csv")

# %%
df1 = pd.read_csv('../data/data_15-12-2025.csv')
df1.head(2)

# %%
df.head(2)

# %%
df.describe()

# %%
df1 = df[df['Quantity'] <= 0]
df1

# %%
df2 = df[df['UnitPrice'] <0]
df2

# %%
df.head(5)

# %%
df.info()

# %%
df.shape

# %%
df['Country'].value_counts()

# %%
df['InvoiceDate'].value_counts()

# %%
df.isna().sum()

# %%
df.columns

# %%
from datetime import datetime
import pandas as pd




df = pd.DataFrame()



df['date']=datetime.now()


df

# %%
url = 'https://raw.githubusercontent.com/SaiD-MH/E-Commerce-ETL-Data-Pipeline/main/data/data_13-12-2025.csv'


df = pd.read_csv(url)

df
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 10092    537225     22831             WHITE BROCANTE SOAP DISH         2
# 10093    537225     20757               RED DAISY POCKET BOOK          3
# 10094    537225     20757               RED DAISY POCKET BOOK          6
# 10095    537225     20764         ABSTRACT CIRCLES SKETCHBOOK          1
# 10096    537225     20770             ABSTRACT CIRCLE JOURNAL          1
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1       12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2       12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3       12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4       12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                ...        ...         ...             ...
# 10092  12/5/2010 16:41       2.95     12748.0  United Kingdom
# 10093  12/5/2010 16:41       0.85     12748.0  United Kingdom
# 10094  12/5/2010 16:41       0.85     12748.0  United Kingdom
# 10095  12/5/2010 16:41       3.75     12748.0  United Kingdom
# 10096  12/5/2010 16:41       2.55     12748.0  United Kingdom
#
# [10097 rows x 8 columns]

# %%
df = pd.DataFrame({'a':[1] , 'b':[2]})
cols = ['a']

x = set(cols) - set(df.columns)

x
# Out:
# set()

# %%
from datetime import datetime


x = datetime.now()

print(x)
# Out:
# 2025-12-31 16:25:36.347808

# %%
import pandas as pd

df = pd.DataFrame([{
    "InvoiceNo": "536365",
    "StockCode": "85123A",
    "Description": "WHITE HANGING HEART T-LIGHT HOLDER",
    "Quantity": 6,
    "InvoiceDate": "2010-12-01",
    "UnitPrice": 2.55,
    "CustomerID": 17850,
    "Country": "United Kingdom",
    "ingestion_date": pd.to_datetime("2025-12-31 16:25:36.347808")
    }])

df
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010-12-01       2.55       17850  United Kingdom
#
#               ingestion_date
# 0 2025-12-31 16:25:36.347808

# %%
#open the file 

import pandas as pd

# %%
df = pd.read_csv("../data/data_14-12-2025.csv")

# %%
df1 = pd.read_csv('../data/data_15-12-2025.csv')
df1.head(2)

# %%
df.head(2)

# %%
df.describe()

# %%
df1 = df[df['Quantity'] <= 0]
df1

# %%
df2 = df[df['UnitPrice'] <0]
df2

# %%
df.head(5)

# %%
df.info()

# %%
df.shape

# %%
df['Country'].value_counts()

# %%
df['InvoiceDate'].value_counts()

# %%
df.isna().sum()

# %%
df.columns

# %%
from datetime import datetime
import pandas as pd




df = pd.DataFrame()



df['date']=datetime.now()


df

# %%
url = f'https://raw.githubusercontent.com/SaiD-MH/E-Commerce-ETL-Data-Pipeline/main/data_13-12-2025.csv'

df = pd.read_csv(url)
